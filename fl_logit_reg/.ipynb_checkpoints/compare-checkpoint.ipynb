# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 对比

# %%
with open('./results/res_center.txt', 'r') as f:
    res_center = []
    for line in f.readlines():
        line = line.strip().split(',')
        res_center.append(line)
res_center_df = pd.DataFrame(pd.array(res_center,dtype=float), columns=['epoch', 'loss_cen', 'acc_cen'])

# %%
res_center_df.set_index('epoch', inplace=True)

# %%
with open('./results/res_fl.txt', 'r') as f:
    res_fl = []
    for line in f.readlines():
        line = line.strip().split(',')
        res_fl.append(line)
res_fl_df = pd.DataFrame(pd.array(res_fl,dtype=float), columns=['epoch', 'loss_fl', 'acc_fl'])

# %%
res_fl_df.set_index('epoch', inplace=True)

# %%
res = pd.concat([res_center_df, res_fl_df], axis=1)

# %%
res
# Out:
#        loss_cen  acc_cen  loss_fl  acc_fl
# epoch
# 1.0      0.5821     0.74   0.5862    0.34
# 2.0      0.5752     0.77   0.5833    0.36
# 3.0      0.5688     0.79   0.5806    0.37
# 4.0      0.5630     0.79   0.5779    0.40
# 5.0      0.5573     0.80   0.5752    0.41
# ...         ...      ...      ...     ...
# 76.0     0.4618     0.93   0.4818    0.91
# 77.0     0.4616     0.93   0.4812    0.91
# 78.0     0.4613     0.93   0.4808    0.91
# 79.0     0.4609     0.93   0.4804    0.91
# 80.0     0.4606     0.93   0.4800    0.91
#
# [80 rows x 4 columns]

# %%
# global_epochs=50
fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1,2,1)
ax1.set_title('loss')
ax2 = fig.add_subplot(1,2,2)
ax2.set_title('acc')
res.iloc[:,[0,2]].plot(ax=ax1)
res.iloc[:, [1,3]].plot(ax=ax2)
# Out:
# <AxesSubplot:title={'center':'acc'}, xlabel='epoch'>

# %%
# global_epochs=80
fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1,2,1)
ax1.set_title('loss')
ax2 = fig.add_subplot(1,2,2)
ax2.set_title('acc')
res.iloc[:,[0,2]].plot(ax=ax1)
res.iloc[:, [1,3]].plot(ax=ax2)
# Out:
# <AxesSubplot:title={'center':'acc'}, xlabel='epoch'>

# %%
# global_epochs=100
fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1,2,1)
ax1.set_title('loss')
ax2 = fig.add_subplot(1,2,2)
ax2.set_title('acc')
res.iloc[:,[0,2]].plot(ax=ax1)
res.iloc[:, [1,3]].plot(ax=ax2)
# Out:
# <AxesSubplot:title={'center':'acc'}, xlabel='epoch'>

# %%
# global_epochs=120
fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1,2,1)
ax1.set_title('loss')
ax2 = fig.add_subplot(1,2,2)
ax2.set_title('acc')
res.iloc[:,[0,2]].plot(ax=ax1)
res.iloc[:, [1,3]].plot(ax=ax2)
# Out:
# <AxesSubplot:title={'center':'acc'}, xlabel='epoch'>

# %%
# global_epochs=150
fig = plt.figure(figsize=(15,5))
ax1 = fig.add_subplot(1,2,1)
ax1.set_title('loss')
ax2 = fig.add_subplot(1,2,2)
ax2.set_title('acc')
res.iloc[:,[0,2]].plot(ax=ax1)
res.iloc[:, [1,3]].plot(ax=ax2)
# Out:
# <AxesSubplot:title={'center':'acc'}, xlabel='epoch'>
